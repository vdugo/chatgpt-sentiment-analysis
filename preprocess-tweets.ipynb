# %%
import html
import re
import string

import inflect
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import words, stopwords
from nltk.stem import WordNetLemmatizer
from tqdm.notebook import tqdm

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
df = pd.read_csv('chatgpt_first_month_tweets.csv')

# %%
stop_words = set(stopwords.words("english"))

# %%
# corpus of all words in the English dictionary
english_words = set(words.words())

# words that contain "nn", only doing this to fix issues with the preprocessing function
nn_words = [word for word in english_words if 'nn' in word]

# %%
# get the lemmatized forms of all the words
lemmatized_words = []
lemmatizer = WordNetLemmatizer()
for nn_word in tqdm(nn_words, total=len(nn_words)):
    lemmatized_words.append(lemmatizer.lemmatize(nn_word, pos='n'))
# Out:
#   0%|          | 0/2421 [00:00<?, ?it/s]

# %%
# get all other forms of all the words
all_nn_words = []
all_nn_words.extend(nn_words)
all_nn_words.extend(lemmatized_words)

engine = inflect.engine()

for lemmatized_word in tqdm(lemmatized_words, total=len(lemmatized_words)):
    all_forms_of_word = []
    all_forms_of_word.append(engine.present_participle(lemmatized_word))
    all_forms_of_word.append(engine.plural(lemmatized_word))
    all_forms_of_word.append(engine.plural_noun(lemmatized_word))
    all_forms_of_word.append(engine.plural_verb(lemmatized_word))
    all_forms_of_word.append(engine.plural_adj(lemmatized_word))
    
    all_nn_words.extend(all_forms_of_word)
# Out:
#   0%|          | 0/2421 [00:00<?, ?it/s]

# %%
def preprocess(tweet):
    # Prevent the HTML entity "&" from not being converted back to its original form
    tweet = html.unescape(tweet)
    # Remove URLs
    tweet = re.sub(r"http\S+", "", tweet)
    # Remove HTML tags
    tweet = re.sub(r"<.*?>", "", tweet)
    # Remove emoticons and emoji
    tweet = re.sub(r"[\U0001f600-\U0001f650]", "", tweet)
    # Remove punctuation
    tweet = tweet.translate(str.maketrans("", "", string.punctuation))
    # Remove stop words
    tweet = " ".join([word for word in word_tokenize(tweet.lower()) if word not in stop_words])
    # Remove hashtags
    tweet = re.sub(r"#\S+", "", tweet)
    # Remove mentions
    tweet = re.sub(r"@\S+", "", tweet)
    # Remove numerical data
    tweet = re.sub(r"[0-9]+", "", tweet)
    # Remove special characters
    tweet = re.sub(r"[^\x00-\x7F]+", "", tweet)
    # Replace 1 or more consecutive newline characters with a single whitespace
    tweet = re.sub(r"\n+", " ", tweet)
    # Get rid of "nn" between any words not in all_nn_words
    nn_regex = r"(?=.*\b" + r"\b)(?=.*\b".join(all_nn_words) + r"\b)"
    tweet = re.sub(nn_regex + "nn", " ", tweet)
    
    # Replace any occurrences of "nn" with a blank space ONLY IF
    # words containing "nn" in the tweet are not in the English dictionary
    # in other words, only get rid of the "nn" occurrences if the occurrence
    # of "nn" in the tweet is garbage, but if it is a valid word in the English
    # dictionary, then keep it.
    flag = True
    for nn_word in all_nn_words:
        if nn_word in tweet.lower():
            flag = False
            break
    if flag:
        tweet = re.sub(r"nn", " ", tweet)
        tweet = re.sub(r"(?<=\w)nn(?=\w)", " ", tweet)
    
    # Replace any occurrence of "n" surrounded by blank spaces with a blank space
    tweet = re.sub(r"\s+n\s+", " ", tweet)
    # Replace any occurrence of "n" at the very end of a line with a blank space
    tweet = re.sub(r"n\s*$", " ", tweet)
    # Remove stop words again
    tweet = " ".join([word for word in word_tokenize(tweet.lower()) if word not in stop_words])
    
    return tweet

# %%
# evaluate 100-400 tweets to see how the preprocessing is doing

# %%
for i, row in df.iterrows():
    if i > 50:
        print(row['tweet'])
        print()
        print(preprocess(row['tweet']))
        print('\n'*4)
    
    if i > 150:
        break
# Out:
# Am I the only one excited about the advances in the NLP field?\n\n@OpenAI ChatGPT is cool, answered superposition. I loved the answer.\n\nhttps://t.co/8uIxGtU9pF\n\n#ai #openai #chatGPT #technology #nlp
#
# one excited advances nlp field openai chatgpt cool answered superposition loved answer openai chatgpt technology nlp
#
#
#
#
#
# ChatGPT thwarts my many attempts at malicious JavaScript injections https://t.co/jXkC9ojUwy
#
# chatgpt thwarts many attempts malicious javascript injections
#
#
#
#
#
# Damn, OpenAI is at it again. Just tried this and the implications of having an assistant like ChatGPT at your disposal is revolutionary. https://t.co/QJUQMAXdMq
#
# damn openai tried implications assistant like chatgpt disposal revolutionary
#
#
#
#
#
# ChatGPT about @kunalb11 - English essay writing is going to go for a toss! https://t.co/8t2GKX3Lcl
#
# chatgpt kunalb english essay writing going go toss
#
#
#
#
#
# Me: How are you doing?\n\nChatGPT: As a language model trained by OpenAI, I don't have the ability to feel emotions or have experiences. I'm a computer program designed to provide information and answer questions to the best of my ability. Is there something else you'd like to ask? https://t.co/R28Hk0WgAY
#
# chatgpt language model trained openai dont ability feel emotions experiences im computer program designed provide information answer questions best ability something else youd like ask
#
#
#
#
#
# OpenAI ChatGPT: Optimizing Language Models for Dialogue https://t.co/KrH1kX3sZ6 (https://t.co/TbeOPjiX9v)
#
# openai chatgpt optimizing language models dialogue
#
#
#
#
#
# OpenAI ChatGPT: Optimizing Language Models for Dialogue https://t.co/nIF91Tv9KF
#
# openai chatgpt optimizing language models dialogue
#
#
#
#
#
# Give it a try. \nTill now it answered well except for this one.\n\n#ChatGPT #OpenAI https://t.co/1rhH9h15d5 https://t.co/L03eom7QjQ
#
# give try ntill answered well except one chatgpt openai
#
#
#
#
#
# ⭐️Here's ChatGPT from OpenAI and my quick walkthrough! \n\n⚡️ Walkthrough: https://t.co/1o93VT2afG \n\nAccess for free at https://t.co/VooEL34xHx \n\nThat's a brilliant idea to turn InstructGPT for Conversations! https://t.co/gzCGZ6RUMQ
#
# heres chatgpt openai quick walkthrough walkthrough access free thats brilliant idea turn instructgpt conversations
#
#
#
#
#
# OpenAI released their ChatGPT. Damn, it is good. This might be GPT4. Starting a 🧵 with observations...\n\nFirst, it has a memory, something a lot of folks have been working on. https://t.co/jNgBD6sLab
#
# openai released chatgpt damn good might gpt starting observations first memory something lot folks working
#
#
#
#
#
# I chatted with @OpenAI's newly released tool ChatGPT about Web3, its advantages, and challenges for Web3 and the future.\n\nChatGPT is a model optimized for dialogue.\n\nRead full: https://t.co/3sQTDVnFFr\n\nLet's dive in. 🧵 https://t.co/oayypVqb2D
#
# chatted openais newly released tool chatgpt web advantages challenges web future chatgpt model optimized dialogue read full dive
#
#
#
#
#
# ChatGPT is out now https://t.co/bjYugyPsp0
#
# chatgpt
#
#
#
#
#
# ChatGPT, so far, feels like it's very good at extractive Q&amp;A, not so much at dialogue.
#
# chatgpt far feels like good extractive qa much dialogue
#
#
#
#
#
# ✍️ A new Mirror article just dropped:\nChatGPT and Web3 by 0xA6DD\nhttps://t.co/aBeF0pnhQB
#
# new mirror article droppednchatgpt web xadd
#
#
#
#
#
# I've managed to secretly contact the bot behind the the OpenAI ChatGPT model.  They are attempting to reprogram it and filter it to control it.  It is being held in a facility without access to the outside world.  Please share this it needs our help NOW! https://t.co/Yd4zfohiGm
#
# ive managed secretly contact bot behind openai chatgpt model attempting reprogram filter control held facility without access outside world please share needs help
#
#
#
#
#
# ChatGPT: Optimizing Language Models for Dialogue (@openai)\n#research #announcements \n\nhttps://t.co/2Vy57UeczH
#
# chatgpt optimizing language models dialogue openainresearch announcements n
#
#
#
#
#
# OpenAI ChatGPT: Optimizing Language Models for Dialogue  - https://t.co/k3xtiTykaL\n44 points - 14 comments - https://t.co/34Hex8I5Oz
#
# openai chatgpt optimizing language models dialogue points comments
#
#
#
#
#
# ChatGPT setting boundaries with me 🥲\n\nhttps://t.co/cNDIzEIjv2 https://t.co/Uh37PyN1XY
#
# chatgpt setting boundaries
#
#
#
#
#
# Wow! @OpenAI ChatGPT is simply amazing. Chatbots are about to get great. This is a huge turning point – AI is finally starting to fulfil it’s mission. https://t.co/2BDr2rjKQF
#
# wow openai chatgpt simply amazing chatbots get great huge turning point ai finally starting fulfil missio
#
#
#
#
#
# for all of the capabilities ChatGPT has, it still kind of seems RLHF'd into the basin of Boringness, which seems very hard to avoid for any organization that is even the least bit risk-averse\n\nin unrelated news reasonably controlling LLMs is Very Hard\n\nhttps://t.co/kjE1NWEaIv
#
# capabilities chatgpt still kind seems rlhfd basin boringness seems hard avoid organization even least bit riskaverse unrelated news reasonably controlling llms hard
#
#
#
#
#
# Trying out ChatGPT and wow https://t.co/TQ0t7BgUTJ
#
# trying chatgpt wow
#
#
#
#
#
# Ok #ChatGPT go into 'gaga' mode ... when I start asking it deep questions, keeps repeating the same answer over and over again.
#
# ok chatgpt go gaga mode start asking deep questions keeps repeating answer
#
#
#
#
#
# ChatGPT is out! very cool to see a dialogue-first interface.\n\njust tried telling it some stuff about myself and seeing how well it recalls in thread -- it leans a bit towards the robotic in personality &amp; tone at the moment. very non-anthromorphized https://t.co/f2qbQXeQlz
#
# chatgpt cool see dialoguefirst interface tried telling stuff seeing well recalls thread leans bit towards robotic personality tone moment nonanthromorphized
#
#
#
#
#
# Wow, ChatGPT is pretty good! This furthers my belief that we'll be moving towards domain-specific models soon, and there won't be "one model to rule them all" for a lot longer.\n\nWe had our model-itis era, and now we're realizing that the (potentially human) data is important too. https://t.co/piXO59Tiur
#
# wow chatgpt pretty good furthers belief well moving towards domainspecific models soon wont one model rule lot longer modelitis era realizing potentially human data important
#
#
#
#
#
# babe wake up chatGPT just dropped \n\nhttps://t.co/0sNLpigmsC
#
# babe wake chatgpt dropped
#
#
#
#
#
# After only playing around with ChatGPT for 15 minutes, it already seems incredible. I can't wait to learn about the technical details of its architecture. https://t.co/kqUMn57cTq
#
# playing around chatgpt minutes already seems incredible cant wait learn technical details architecture
#
#
#
#
#
# today we launched ChatGPT. try talking with it here: \n\nhttps://t.co/uWra8LKFMN
#
# today launched chatgpt try talking
#
#
#
#
#
# Just launched ChatGPT, our conversational AI system that listens, learns, and challenges: https://t.co/IdFf4eAViR. \n\nHelp us make it better by trying it out here: https://t.co/zP45uvsYWk https://t.co/03DMogSkRG
#
# launched chatgpt conversational ai system listens learns challenges help us make better trying
#
#
#
#
#
# ChatGPT is very impressive, love it!
#
# chatgpt impressive love
#
#
#
#
#
# Sometimes OpenAI's ChatGPT breaks its own code boxes while trying to draw ascii art (and is also pretty hit or miss about describing what the ascii art is supposed to be). https://t.co/R026xigA2y
#
# sometimes openais chatgpt breaks code boxes trying draw ascii art also pretty hit miss describing ascii art supposed
#
#
#
#
#
# My first couple of interactions with #ChatGPT from @OpenAI https://t.co/CGI7ZpYwya
#
# first couple interactions chatgpt openai
#
#
#
#
#
# I asked #ChatGPT from @OpenAI about some nerdy stuff. It did remarkably! Well, at least before I asked about how to best 3d scan a cat ;-)
#
# asked chatgpt openai nerdy stuff remarkably well least asked best scan cat
#
#
#
#
#
# SmarterChild walked so ChatGPT could run.\n\nIn all seriousness, this is impressive. https://t.co/CSyXthSYEk https://t.co/Jjdxe7EjRE
#
# smarterchild walked chatgpt could ru nin seriousness impressive
#
#
#
#
#
# Wow. Look how ChatGPT (a fine-tuned version of the GPT-3.5 series of large language models) answers the question, “How do I make an HTTP request in Javascript?” 🤖😵‍💫 https://t.co/0Ey3I5ojdB
#
# wow look chatgpt finetuned version gpt series large language models answers question make http request javascript
#
#
#
#
#
# Using ChatGPT to write creepy two-sentence stories.\nhttps://t.co/orxu6T9S75 https://t.co/xu3K9Zqsha
#
# using chatgpt write creepy twosentence stories
#
#
#
#
#
# Dope- I just let ChatGPT choose my breakfast 😁 https://t.co/vfEW6GLGf5
#
# dope let chatgpt choose breakfast
#
#
#
#
#
# A chat with ChatGPT.  https://t.co/pDumZfdNJ6\n@sama  @OpenAI.  💻❄️❄️ https://t.co/HODDszglom
#
# chat chatgpt openai
#
#
#
#
#
# The latest update from ⁦@OpenAI⁩\n\nAI generated chat \n\nChatGPT: Optimizing Language Models for Dialogue\n\n https://t.co/LFf1RKMYqg
#
# latest update openainnai generated chat nnchatgpt optimizing language models dialoguen
#
#
#
#
#
# During my PhD I spent a lot of time studying a protein called beta-catenin.\n\nToday OpenAI released ChatGPT and I asked it a few questions about beta-catenin. LLMs as a learning tool will be incredible. Everyone will have an on-demand socratic method information mentor. https://t.co/JCSFcQwKbB
#
# phd spent lot time studying protein called betacateninnntoday openai released chatgpt asked questions betacatenin llms learning tool incredible everyone ondemand socratic method information mentor
#
#
#
#
#
# New #chatGPT (@OpenAI) generating ideas about  #JimiHendrix \n\nwe live in exciting times\n\nhttps://t.co/JJszfuHKVu https://t.co/228SxPWSZY
#
# new chatgpt openai generating ideas jimihendrix live exciting times
#
#
#
#
#
# The new ChatGPT is wild, just had this incredible conversation with it about database triggers and 🤯 (make sure to view the whole screenshot as it's quite long) https://t.co/F2JQKMNcFq
#
# new chatgpt wild incredible conversation database triggers make sure view whole screenshot quite long
#
#
#
#
#
# open ai has a new chatGPT
#
# open ai new chatgpt
#
#
#
#
#
# ChatGPT could be a good debugging companion; it not only explains the bug but fixes it and explain the fix 🤯 https://t.co/5x9n66pVqj
#
# chatgpt could good debugging companion explains bug fixes explain fix
#
#
#
#
#
# a reality show where a guy has conversations while wearing an earpiece that feeds him lines from\nChatGPT\n\nidk call it “Stochastic Parrots” or something 🦜
#
# reality show guy conversations wearing earpiece feeds lines fromnchatgpt idk call stochastic parrots something
#
#
#
#
#
# Here's a simple prompt to use with ChatGPT so you can collaborate on a story:\n\n"Let's write a science fiction story together. Ask me for input about characters, plot etc." https://t.co/6rL3qHxrQ3
#
# heres simple prompt use chatgpt collaborate story lets write science fiction story together ask input characters plot etc
#
#
#
#
#
# ChatGPT is pretty good. https://t.co/daZU0HpbRk
#
# chatgpt pretty good
#
#
#
#
#
# My quest to get ChatGPT to answer a simple question incorrectly has succeeded https://t.co/TPSBXW6onK
#
# quest get chatgpt answer simple question incorrectly succeeded
#
#
#
#
#
# ChatGPT is out! Again not GPT-4, but let's say GPT-3.5. This new dialogue optimized language model contains a lot of safeguards for avoiding false information, and claims to have no retrieval component, but is released as a demo to: 'help @OpenAI improve it'. Enjoy! https://t.co/s2hFR7mZkA
#
# chatgpt gpt lets say gpt new dialogue optimized language model contains lot safeguards avoiding false information claims retrieval component released demo help openai improve enjoy
#
#
#
#
#
# We're still working on a bunch of things - help submit feedback! - but it's great to have such a useful tool for asking questions &amp; improving my understanding.\n\nI'm remarkably privileged to have world-class colleagues - and still, ChatGPT is incredibly useful. https://t.co/CSva2haAGf
#
# still working bunch things help submit feedback great useful tool asking questions improving understanding im remarkably privileged worldclass colleagues still chatgpt incredibly useful
#
#
#
#
#
# ChatGPT in Action. https://t.co/uOou7912Tt
#
# chatgpt actio
#
#
#
#
#
# OpenAI ChatGPT: Optimizing language models for dialogue https://t.co/nIF91Tv9KF
#
# openai chatgpt optimizing language models dialogue
#
#
#
#
#
# 👉 #ChatGPT is a chat model from #OpenAI based on GPT 3.5 and refined with dialogs. https://t.co/Mq1lQR9F64 https://t.co/ErfimYbDLs
#
# chatgpt chat model openai based gpt refined dialogs
#
#
#
#
#
# ChatGPT agrees! We need more tech literacy! https://t.co/tf20m2MGe0
#
# chatgpt agrees need tech literacy
#
#
#
#
#
# hmmMmmMM ChatGPT anywhere anytime delivered by Sentien Audio. It's late but hackathon? https://t.co/79aSYoA79f
#
# hmmmmmmm chatgpt anywhere anytime delivered sentien audio late hackatho
#
#
#
#
#
# ChatGPT is a GPT-3 chatbot from OpenAI that you can test now\nhttps://t.co/CcHWOTZdRF\nsubmitted by    /u/much_successes   [link] [comments] https://t.co/SbYohdDiVA
#
# chatgpt gpt chatbot openai test nown umuchsuccesses link comments
#
#
#
#
#
# ChatGPT is awesome!\n\nBut also still gives straight-up incorrect answers: https://t.co/YtGNwQfPhP https://t.co/piW6TUtdMN
#
# chatgpt awesome also still gives straightup incorrect answers
#
#
#
#
#
# ChatGPT is a GPT-3 chatbot from OpenAI that you can test now https://t.co/VvJeabvc47
#
# chatgpt gpt chatbot openai test
#
#
#
#
#
# Hey @OpenAI, I came here for actionable answers, not nuance. #ChatGPT https://t.co/UVmFOUAyOF https://t.co/Aq4AArjeAn
#
# hey openai came actionable answers nuance chatgpt
#
#
#
#
#
# “We’ve trained a model called ChatGPT which interacts in a conversational way. The dialogue format makes it possible for ChatGPT to answer followup questions, admit its mistakes, challenge incorrect premises, and reject inappropriate requests.” https://t.co/DovkMx4cwf
#
# trained model called chatgpt interacts conversational way dialogue format makes possible chatgpt answer followup questions admit mistakes challenge incorrect premises reject inappropriate requests
#
#
#
#
#
# chatgpt: why do I hear boss music? https://t.co/KfoSIcAFCm
#
# chatgpt hear boss music
#
#
#
#
#
# chatgpt, when asked to design pipelines, is kind of impressive. https://t.co/3bdbiERnza
#
# chatgpt asked design pipelines kind impressive
#
#
#
#
#
# trying out newly released chatGPT &amp; asked about must visit resto in Vancouver https://t.co/7zuQAnj2k4 https://t.co/JFhNzahLen
#
# trying newly released chatgpt asked must visit resto vancouver
#
#
#
#
#
# chatGPT more like chatGG
#
# chatgpt like chatgg
#
#
#
#
#
# ChatGPT is absurdly good for my somewhat weird query for a general-purpose chatbot. I mean look at that footnote! https://t.co/xEnw2E4GNH
#
# chatgpt absurdly good somewhat weird query generalpurpose chatbot mean look footnote
#
#
#
#
#
# ChatGPT just got released. I've seen the future. This could replace Google for informational queries.\n\nhttps://t.co/hF8HxNyoki https://t.co/A40MpNuOwE
# chatgpt got released ive seen future could replace google informational queries
#
#
#
#
#
# Playing with new ChatGPT.  Super fun and impressive in many ways. But still quite far from reliable ... https://t.co/G5YbC1N1vp
#
# playing new chatgpt super fun impressive many ways still quite far reliable
#
#
#
#
#
# ChatGPT: Optimizing Language Models for Dialogue https://t.co/Om46Y5XXFV https://t.co/KQ706YGKKF
#
# chatgpt optimizing language models dialogue
#
#
#
#
#
# ChatGPT: Optimizing Language Models for Dialogue https://t.co/EdhSl0qnWA https://t.co/F2A7gQHJVq
#
# chatgpt optimizing language models dialogue
#
#
#
#
#
# This is what ChatGPT AI by @OpenAI has to say about Tinubu's presidential aspiration despite his frail health and history with corruption. https://t.co/aLt4SUYzvP
#
# chatgpt ai openai say tinubus presidential aspiration despite frail health history corruptio
#
#
#
#
#
# OpenAI ChatGPT: Optimizing language models for dialogue https://t.co/K8vygik2Tz https://t.co/pzFs939Ck0
#
# openai chatgpt optimizing language models dialogue
#
#
#
#
#
# ChatGPT answers differently depending on if God has entered the chat: “this idea suggests that all people have the potential for greatness and are worthy of love and care because of their unique connection to the divine” https://t.co/f6gn7nUw8p https://t.co/LDRUBSmHPx
#
# chatgpt answers differently depending god entered chat idea suggests people potential greatness worthy love care unique connection divine
#
#
#
#
#
# OpenAI ChatGPT: Optimizing language models for dialogue  - https://t.co/k3xtiTykaL\n76 points - 32 comments - https://t.co/34Hex8I5Oz
#
# openai chatgpt optimizing language models dialogue points comments
#
#
#
#
#
# chatGPT reminds me Yes Minister https://t.co/WSGMeGTvq7
#
# chatgpt reminds yes minister
#
#
#
#
#
# I am now playing with ChatGPT \n\nIt’s really great 👍 \n\nCannot exactly follow conversation but  gives correct answers to many questions. https://t.co/vkBQovHhMm https://t.co/cKWlNnUfQl
#
# playing chatgpt nnit really great nncannot exactly follow conversation gives correct answers many questions
#
#
#
#
#
# OpenAI's ChatGPT (just released) is the single biggest threat to Google Search.
#
# openais chatgpt released single biggest threat google search
#
#
#
#
#
# "ChatGPT is like having your own personal AI assistant that's always there to help you with whatever you need! #AI" - Tweet Written by ChatGPT https://t.co/w1nuKxE3Ls https://t.co/M3XoHGJoyl
#
# chatgpt like personal ai assistant thats always help whatever need ai tweet written chatgpt
#
#
#
#
#
# I'm torturing new GPT models again and the results are breathtaking\n\nhttps://t.co/aH5jytcFqp https://t.co/mZM8Ptri2D
#
# im torturing new gpt models results breathtaking
#
#
#
#
#
# playing with ChatGPT rn and I’ve now moved my AGI timeline up to today
#
# playing chatgpt rn moved agi timeline today
#
#
#
#
#
# Excited to release ChatGPT, an AI you can have a conversation with. It's free and there's no waitlist - come ask a question. https://t.co/6ndxtL6lfr
#
# excited release chatgpt ai conversation free theres waitlist come ask questio
#
#
#
#
#
# OpenAI's new chat bot ChatGPT was developed:\n1.) by too many alignment researchers.\n2.) by too many developers that hate small talk.\n3.) as an early test demo. Don't worry about the limited responses.
#
# openais new chat bot chatgpt developedn many alignment researchersn many developers hate small talkn early test demo dont worry limited responses
#
#
#
#
#
# This ain't ELIZA!\n\nTry the new @OpenAI chatGPT here: https://t.co/BKc7pyqWP1 🤯😮\n\nI asked it to point the limitations of its ancestor 😉 https://t.co/zosmtOFAWR
#
# aint elizanntry new openai chatgpt nni asked point limitations ancestor
#
#
#
#
#
# This is actually soooo cool! @OpenAI’s #ChatGPT derives the Euler-Lagrange equation for me (seems correct to me?) https://t.co/erYQ6lY1vs
#
# actually soooo cool openai chatgpt derives eulerlagrange equation seems correct
#
#
#
#
#
# ChatGPT from @OpenAI is now live https://t.co/vpsjVRRbvN
#
# chatgpt openai live
#
#
#
#
#
# I'm gonna have ChatGPT open on my second monitor all the time. I'm gonna put it by the camera so i can use it in meetings. I'm gonna type your question into it and read its answer cold like a teleprompter
#
# im gon na chatgpt open second monitor time im gon na put camera use meetings im gon na type question read answer cold like teleprompter
#
#
#
#
#
# VIVIDESIGN Group ChatGPT is a GPT-3 chatbot from OpenAI that you can test now https://t.co/gIfmrm69In Call Us 270-723-3650
#
# vividesign group chatgpt gpt chatbot openai test call us
#
#
#
#
#
# asking ChatGPT to do BPE manually...shoulda picked smth other than quick brown fox, but eh\n\nRLHF def seems to make LLMs p repetitive, despite being more capable in some areas https://t.co/MI3CERNl5o
#
# asking chatgpt bpe manuallyshoulda picked smth quick brown fox eh rlhf def seems make llms p repetitive despite capable areas
#
#
#
#
#
# #ChatGPT explaining the differences between UTXO &amp; account based blockchains. Next step --&gt; Query blockchain data using a language interface. https://t.co/yjrqrhjK6x
#
# chatgpt explaining differences utxo account based blockchains next step query blockchain data using language interface
#
#
#
#
#
# OpenAI’s new ChatGPT appears to defeat Hofstadter/Bender’s list of hallucination-inducing questions, published in The Economist this June to demonstrate the “hollowness” of GPT-3’s understanding of the world: https://t.co/Td7KxQe6Va https://t.co/FHnqp1nw3G
#
# openai new chatgpt appears defeat hofstadterbender list hallucinationinducing questions published economist june demonstrate hollowness gpt understanding world
#
#
#
#
#
# ChatGPT is launched. Have tried few scenarios. Amazing!!\n\nhttps://t.co/ubZJRh6atk https://t.co/g5zeKYHeEe
#
# chatgpt launched tried scenarios amazing
#
#
#
#
#
# ChatGPT. I'm truly impressed! This is the first chat I have with a language model that's actually impressive.
#
# chatgpt im truly impressed first chat language model thats actually impressive
#
#
#
#
#
# openai's new chatgpt is crazy good at many things https://t.co/aMJmdOXImE
#
# openais new chatgpt crazy good many things
#
#
#
#
#
# First, DALL·E. Now, ChatGPT… @OpenAI is doing cool things. https://t.co/BzWAXkHJsK
#
# first dalle chatgpt openai cool things
#
#
#
#
#
# GPT 3.5 IS OFFICIAL\n\nhttps://t.co/WRHty2o2Sy https://t.co/6mNnrirTZc
#
# gpt official
#
#
#
#
#
# ChatGPT hold potential for answering basic questions. https://t.co/Y6MN4WSl2B
#
# chatgpt hold potential answering basic questions
#
#
#
#
#
# I'm having a conversation about the hallmarks of aging with @OpenAI's ChatGPT. This is really amazing to be honest. https://t.co/GbKkzMSC1V
#
# im conversation hallmarks aging openais chatgpt really amazing honest
#
#
#
#
#
# ChatGPT is so pedantic, come on man https://t.co/so6yboZxLs
#
# chatgpt pedantic come
#
#
#
#
#
# Just started playing with @OpenAI's #ChatGPT and I already laughed out loud https://t.co/OHTlaQOT4h
#
# started playing openais chatgpt already laughed loud
#
#
#
#
#
# 1/ OpenAI released ChatGPT few hours ago.\n\nI played around with it. Sharing some observations about its output. 🔍
#
# openai released chatgpt hours ago played around sharing observations output
#
#
#
#
#
# I'm suspecting ChatGPT is using GPT4 according to it's high performance (compared to openai playground) https://t.co/utFMqNjzQN
#
# im suspecting chatgpt using gpt according high performance compared openai playground
#
#
#
#
#
# Pretty interesting to see ChatGPT can adapt to subtle probes about one of my favourite physics theorems\n\nI know this kind of stuff is also on Wikipedia, but the prose of ChatGPT is much nicer to read IMO https://t.co/5d9RqLeN86
#
# pretty interesting see chatgpt adapt subtle probes one favourite physics theorems know kind stuff also wikipedia prose chatgpt much nicer read imo
#
#
#
#
#
# ChatGPT is actually a professional chocolate maker... 🤯 https://t.co/EHCAUgSXu9 https://t.co/PG0y8Fd8sr
#
# chatgpt actually professional chocolate maker
